# %% [markdown]
# <a href="https://colab.research.google.com/github/kritshan/Big-Data-Projects/blob/main/Neural%20Networks/RNN_CF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow.compat.v1 as tf
import numpy as np
import urllib
tf.compat.v1.disable_eager_execution()

# the number of iterations to train for
numTrainingIters = 10000

# the number of hidden neurons that hold the state of the RNN
hiddenUnits = 500

# the number of classes that we are learning over
numClasses = 3

# the number of data points in a batch
batchSize = 100

# this function takes a dictionary (called data) which contains
# of (dataPointID, (classNumber, matrix)) entries.  Each matrix
# is a sequence of vectors; each vector has a one-hot-encoding of
# an ascii character, and the sequence of vectors corresponds to
# one line of text.  classNumber indicates which file the line of
# text came from.
#
# The argument maxSeqLen is the maximum length of a line of text
# seen so far.  fileName is the name of a file whose contents
# we want to add to data.  classNum is an indicator of the class
# we are going to associate with text from that file.  linesToUse
# tells us how many lines to sample from the file.
#
# The return val is the new maxSeqLen, as well as the new data
# dictionary with the additional lines of text added
def addToData (maxSeqLen, data, testData, fileName, classNum, linesToUse):
    #
    # open the file and read it in
    response = urllib.request.urlopen(fileName)
    content = response.readlines ()
    #
    # sample linesToUse numbers; these will tell us what lines
    # from the text file we will use
    myInts = np.random.choice(len(content), size=linesToUse + 1000, replace=False)
    testInts = myInts[-2000:]
    trainingInts = myInts[:10000]
    #
    # i is the key of the next line of text to add to the dictionary
    i = len(data)
    #
    # loop thru and add the lines of text to the dictionary
    for whichLine in trainingInts.flat:
        #
        # get the line and ignore it if it has nothing in it
        line = content[whichLine].decode("utf-8")
        if line.isspace () or len(line) == 0:
            continue;
        #
        # take note if this is the longest line we've seen
        if len (line) > maxSeqLen:
            maxSeqLen = len (line)
        #
        # create the matrix that will hold this line
        temp = np.zeros((len(line), 256))
        #
        # j is the character we are on
        j = 0
        #
        # loop thru the characters
        for ch in line:
            #
            # non-ascii? ignore
            if ord(ch) >= 256:
                continue
            #
            # one hot!
            temp[j][ord(ch)] = 1
            #
            # move onto the next character
            j = j + 1
            #
        # remember the line of text
        data[i] = (classNum, temp)
        #
        # move onto the next line
        i = i + 1
    #
    # and return the dictionary with the new data

    testI = len(testData)
    for whichLine in testInts.flat:
        if len(testData) == 3000:
            break
        line = content[whichLine].decode("utf-8")
        if line.isspace () or len(line) == 0:
            continue;
        #
        # take note if this is the longest line we've seen
        if len (line) > maxSeqLen:
            maxSeqLen = len (line)
        #
        # create the matrix that will hold this line
        temp = np.zeros((len(line), 256))
        #
        # j is the character we are on
        j = 0
        #
        # loop thru the characters
        for ch in line:
            #
            # non-ascii? ignore
            if ord(ch) >= 256:
                continue
            #
            # one hot!
            temp[j][ord(ch)] = 1
            #
            # move onto the next character
            j = j + 1
            #
        # remember the line of text
        testData[testI] = (classNum, temp)
        #
        # move onto the next line
        testI = testI + 1

    return (maxSeqLen, data), (maxSeqLen, testData)

# this function takes as input a data set encoded as a dictionary
# (same encoding as the last function) and pre-pends every line of
# text with empty characters so that each line of text is exactly
# maxSeqLen characters in size
def pad (maxSeqLen, data):
   #
   # loop thru every line of text
   for i in data:
        #
        # access the matrix and the label
        temp = data[i][1]
        label = data[i][0]
        #
        # get the number of chatacters in this line
        len = temp.shape[0]
        #
        # and then pad so the line is the correct length
        padding = np.zeros ((maxSeqLen - len,256))
        data[i] = (label, np.transpose (np.concatenate ((padding, temp), axis = 0)))
   #
   # return the new data set
   return data

# this generates a new batch of training data of size batchSize from the
# list of lines of text data. This version of generateData is useful for
# an RNN because the data set x is a NumPy array with dimensions
# [batchSize, 256, maxSeqLen]; it can be unstacked into a series of
# matrices containing one-hot character encodings for each data point
# using tf.unstack(inputX, axis=2)
def generateDataRNN (maxSeqLen, data):
    #
    # randomly sample batchSize lines of text
    myInts = np.random.randint (0, len(data), batchSize)
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack ([data[i][1] for i in myInts.flat])
    #
    # and stack all of the labels into a vector of labels
    y = np.stack ([np.array((data[i][0])) for i in myInts.flat])
    #
    # return the pair
    return (x, y)

# this also generates a new batch of training data, but it represents
# the data as a NumPy array with dimensions [batchSize, 256 * maxSeqLen]
# where for each data point, all characters have been appended.  Useful
# for feed-forward network training
def generateDataFeedForward (maxSeqLen, data):
    #
    # randomly sample batchSize lines of text
    myInts = np.random.randint (0, len(data), batchSize)
    #
    # stack all of the text into a matrix of one-hot characters
    x = np.stack (data[i][1].flatten () for i in myInts.flat)
    #
    # and stack all of the labels into a vector of labels
    y = np.stack (np.array((data[i][0])) for i in myInts.flat)
    #
    # return the pair
    return (x, y)

# create the data dictionary
maxSeqLen = 0
data = {}
testData = {}

# load up the three data sets
(maxSeqLen, data), (maxSeqLen, testData) = addToData (maxSeqLen, data, testData, "https://s3.amazonaws.com/chrisjermainebucket/text/Holmes.txt", 0, 11000)
(maxSeqLen, data), (maxSeqLen, testData) = addToData (maxSeqLen, data, testData, "https://s3.amazonaws.com/chrisjermainebucket/text/war.txt", 1, 11000)
(maxSeqLen, data), (maxSeqLen, testData) = addToData (maxSeqLen, data, testData, "https://s3.amazonaws.com/chrisjermainebucket/text/william.txt", 2, 11000)

# pad each entry in the dictionary with empty characters as needed so
# that the sequences are all of the same length
data = pad (maxSeqLen, data)
testData = pad (maxSeqLen, testData)

# now we build the TensorFlow computation... there are two inputs,
# a batch of text lines and a batch of labels
inputX = tf.placeholder(tf.float32, [batchSize, 256, maxSeqLen])
inputY = tf.placeholder(tf.int32, [batchSize])

# this is the inital state of the RNN, before processing any data
initialState = tf.placeholder(tf.float32, [batchSize, hiddenUnits])

# the weight matrix that maps the inputs and hidden state to a set of values
Wfir = tf.Variable(np.random.normal(0, 0.05, (1008, hiddenUnits)), dtype=tf.float32)

# weights and bias for the final classification
W2 = tf.Variable(np.random.normal (0, 0.05, (hiddenUnits, numClasses)),dtype=tf.float32)
b2 = tf.Variable(np.zeros((1,numClasses)), dtype=tf.float32)

# unpack the input sequences so that we have a series of matrices,
# each of which has a one-hot encoding of the current character from
# every input sequence
sequenceOfLetters = tf.unstack(inputX, axis=2)

filter = tf.Variable(np.random.normal(0, 0.05, (2560, 8)), dtype=tf.float32)


# now we implement the forward pass
currentState = initialState
saved_states = []
time = 0
for r in range(len(sequenceOfLetters)):
    if r >= len(sequenceOfLetters) - 10:
        break
    temp = sequenceOfLetters[r]
    for j in range(1, 10):
        temp = tf.concat([temp, sequenceOfLetters[r+j]], 1)

    filtInput = tf.matmul(temp, filter)

    inputPlusState = tf.concat([filtInput, currentState, saved_states[time-10] if time >= 10 else initialState], 1)
    next_state = tf.tanh(tf.matmul(inputPlusState, Wfir))
    currentState = next_state
    saved_states.append(currentState)
    time += 1


# compute the set of outputs
outputs = tf.matmul(currentState, W2) + b2

predictions = tf.nn.softmax(outputs)

# compute the loss
losses = tf.nn.sparse_softmax_cross_entropy_with_logits(logits=outputs, labels=inputY)
totalLoss = tf.reduce_mean(losses)

# use gradient descent to train
trainingAlg = tf.compat.v1.train.AdagradOptimizer(0.01).minimize(totalLoss)

# and train!!
with tf.Session() as sess:
    #
    # initialize everything
    sess.run(tf.compat.v1.global_variables_initializer())
    #
    # and run the training iters
    for epoch in range(numTrainingIters):
        #
        # get some data
        x, y = generateDataRNN (maxSeqLen, data)
        #
        # do the training epoch
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _trainingAlg, _currentState, _predictions, _outputs = sess.run(
                [totalLoss, trainingAlg, currentState, predictions, outputs],
                feed_dict={
                    inputX:x,
                    inputY:y,
                    initialState:_currentState
                })
        #
        # just FYI, compute the number of correct predictions
        numCorrect = 0
        for i in range (len(y)):
           maxPos = -1
           maxVal = 0.0
           for j in range (numClasses):
               if maxVal < _predictions[i][j]:
                   maxVal = _predictions[i][j]
                   maxPos = j
           if maxPos == y[i]:
               numCorrect = numCorrect + 1
        #
        # print out to the screen
        print("Step", epoch, "Loss", _totalLoss, "Correct", numCorrect, "out of", batchSize)

    testX = np.stack ([testData[i][1] for i in testData])
    testY = np.stack ([testData[i][0] for i in testData])
    numCorrect = 0
    losses = []
    for i in range(30):
        x = testX[(i*batchSize):((i+1) * batchSize)]
        y = testY[(i*batchSize):((i+1) * batchSize)]
        #
        # do the training epoch
        _currentState = np.zeros((batchSize, hiddenUnits))
        _totalLoss, _predictions = sess.run(
                [totalLoss, predictions],
                feed_dict={
                    inputX:x,
                    inputY:y,
                    initialState:_currentState
                })
        losses.append(_totalLoss)
        #
        # just FYI, compute the number of correct predictions
        for i in range (len(y)):
           maxPos = -1
           maxVal = 0.0
           for j in range (numClasses):
               if maxVal < _predictions[i][j]:
                   maxVal = _predictions[i][j]
                   maxPos = j
           if maxPos == y[i]:
               numCorrect = numCorrect + 1
    totalLosses = np.mean(losses)
    print("Loss for 3000 randomly chosen documents is", totalLosses, "correct labels is", numCorrect, "out of 3000")
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.10/dist-packages/tensorflow/python/training/adagrad.py:138: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Step 5985 Loss 0.0888347 Correct 96 out of 100
# ...
# Step 9676 Loss 0.036743227 Correct 99 out of 100
# Step 9677 Loss 0.013514548 Correct 100 out of 100
# Step 9678 Loss 0.008732354 Correct 100 out of 100
# Step 9679 Loss 0.01311502 Correct 99 out of 100
# Step 9680 Loss 0.07285705 Correct 99 out of 100
# Step 9681 Loss 0.010448755 Correct 100 out of 100
# Step 9682 Loss 0.025377795 Correct 99 out of 100
# Step 9683 Loss 0.045370642 Correct 98 out of 100
# Step 9684 Loss 0.010159496 Correct 100 out of 100
# Step 9685 Loss 0.09319176 Correct 97 out of 100
# Step 9686 Loss 0.038168646 Correct 98 out of 100
# Step 9687 Loss 0.06720729 Correct 99 out of 100
# Step 9688 Loss 0.010480395 Correct 100 out of 100
# Step 9689 Loss 0.04483349 Correct 98 out of 100
# Step 9690 Loss 0.029163148 Correct 99 out of 100
# Step 9691 Loss 0.016731506 Correct 99 out of 100
# Step 9692 Loss 0.045219246 Correct 99 out of 100
# Step 9693 Loss 0.053482488 Correct 99 out of 100
# Step 9694 Loss 0.056514267 Correct 99 out of 100
# Step 9695 Loss 0.011996844 Correct 100 out of 100
# Step 9696 Loss 0.019135565 Correct 100 out of 100
# Step 9697 Loss 0.05259632 Correct 98 out of 100
# Step 9698 Loss 0.047036134 Correct 98 out of 100
# Step 9699 Loss 0.011012923 Correct 100 out of 100
# Step 9700 Loss 0.025308246 Correct 99 out of 100
# Step 9701 Loss 0.07094725 Correct 98 out of 100
# Step 9702 Loss 0.019820675 Correct 99 out of 100
# Step 9703 Loss 0.118122965 Correct 98 out of 100
# Step 9704 Loss 0.026044881 Correct 99 out of 100
# Step 9705 Loss 0.026489018 Correct 100 out of 100
# Step 9706 Loss 0.03235615 Correct 99 out of 100
# Step 9707 Loss 0.035196315 Correct 98 out of 100
# Step 9708 Loss 0.101894006 Correct 96 out of 100
# Step 9709 Loss 0.032024775 Correct 98 out of 100
# Step 9710 Loss 0.0071731047 Correct 100 out of 100
# Step 9711 Loss 0.061906546 Correct 97 out of 100
# Step 9712 Loss 0.017082244 Correct 100 out of 100
# Step 9713 Loss 0.0737393 Correct 97 out of 100
# Step 9714 Loss 0.01068549 Correct 100 out of 100
# Step 9715 Loss 0.018360548 Correct 99 out of 100
# Step 9716 Loss 0.041515727 Correct 99 out of 100
# Step 9717 Loss 0.024014182 Correct 99 out of 100
# Step 9718 Loss 0.012298411 Correct 100 out of 100
# Step 9719 Loss 0.022277134 Correct 100 out of 100
# Step 9720 Loss 0.0812223 Correct 97 out of 100
# Step 9721 Loss 0.027225869 Correct 100 out of 100
# Step 9722 Loss 0.021230724 Correct 99 out of 100
# Step 9723 Loss 0.018731685 Correct 99 out of 100
# Step 9724 Loss 0.05609332 Correct 98 out of 100
# Step 9725 Loss 0.022161635 Correct 99 out of 100
# Step 9726 Loss 0.018927364 Correct 100 out of 100
# Step 9727 Loss 0.081130505 Correct 98 out of 100
# Step 9728 Loss 0.031532686 Correct 99 out of 100
# Step 9729 Loss 0.025598442 Correct 100 out of 100
# Step 9730 Loss 0.05584652 Correct 97 out of 100
# Step 9731 Loss 0.057360306 Correct 97 out of 100
# Step 9732 Loss 0.017307509 Correct 100 out of 100
# Step 9733 Loss 0.061253544 Correct 98 out of 100
# Step 9734 Loss 0.015955284 Correct 100 out of 100
# Step 9735 Loss 0.05917004 Correct 98 out of 100
# Step 9736 Loss 0.01647536 Correct 99 out of 100
# Step 9737 Loss 0.009020123 Correct 100 out of 100
# Step 9738 Loss 0.014985859 Correct 100 out of 100
# Step 9739 Loss 0.03794545 Correct 99 out of 100
# Step 9740 Loss 0.013699711 Correct 100 out of 100
# Step 9741 Loss 0.050303306 Correct 99 out of 100
# Step 9742 Loss 0.01021307 Correct 100 out of 100
# Step 9743 Loss 0.046559114 Correct 99 out of 100
# Step 9744 Loss 0.0062362407 Correct 100 out of 100
# Step 9745 Loss 0.07010088 Correct 99 out of 100
# Step 9746 Loss 0.010891296 Correct 100 out of 100
# Step 9747 Loss 0.02702415 Correct 99 out of 100
# Step 9748 Loss 0.017813284 Correct 100 out of 100
# Step 9749 Loss 0.12636083 Correct 95 out of 100
# Step 9750 Loss 0.029873148 Correct 99 out of 100
# Step 9751 Loss 0.015866235 Correct 99 out of 100
# Step 9752 Loss 0.010952699 Correct 100 out of 100
# Step 9753 Loss 0.079329334 Correct 96 out of 100
# Step 9754 Loss 0.013067823 Correct 100 out of 100
# Step 9755 Loss 0.04099768 Correct 99 out of 100
# Step 9756 Loss 0.021306764 Correct 99 out of 100
# Step 9757 Loss 0.012627319 Correct 100 out of 100
# Step 9758 Loss 0.039628554 Correct 98 out of 100
# Step 9759 Loss 0.018081518 Correct 100 out of 100
# Step 9760 Loss 0.009696102 Correct 100 out of 100
# Step 9761 Loss 0.004558195 Correct 100 out of 100
# Step 9762 Loss 0.013660457 Correct 100 out of 100
# Step 9763 Loss 0.04089851 Correct 98 out of 100
# Step 9764 Loss 0.016748779 Correct 100 out of 100
# Step 9765 Loss 0.008558565 Correct 100 out of 100
# Step 9766 Loss 0.042543724 Correct 99 out of 100
# Step 9767 Loss 0.022941094 Correct 99 out of 100
# Step 9768 Loss 0.014426413 Correct 100 out of 100
# Step 9769 Loss 0.024263527 Correct 99 out of 100
# Step 9770 Loss 0.024600333 Correct 100 out of 100
# Step 9771 Loss 0.051249657 Correct 99 out of 100
# Step 9772 Loss 0.023254188 Correct 100 out of 100
# Step 9773 Loss 0.031393405 Correct 100 out of 100
# Step 9774 Loss 0.008115124 Correct 100 out of 100
# Step 9775 Loss 0.09011971 Correct 97 out of 100
# Step 9776 Loss 0.05486129 Correct 97 out of 100
# Step 9777 Loss 0.038425438 Correct 99 out of 100
# Step 9778 Loss 0.12026156 Correct 95 out of 100
# Step 9779 Loss 0.040104423 Correct 98 out of 100
# Step 9780 Loss 0.015950764 Correct 99 out of 100
# Step 9781 Loss 0.07312957 Correct 96 out of 100
# Step 9782 Loss 0.012737586 Correct 100 out of 100
# Step 9783 Loss 0.026952248 Correct 100 out of 100
# Step 9784 Loss 0.014070604 Correct 99 out of 100
# Step 9785 Loss 0.0966053 Correct 96 out of 100
# Step 9786 Loss 0.00595078 Correct 100 out of 100
# Step 9787 Loss 0.024105567 Correct 99 out of 100
# Step 9788 Loss 0.0033283865 Correct 100 out of 100
# Step 9789 Loss 0.015435544 Correct 100 out of 100
# Step 9790 Loss 0.0077082124 Correct 100 out of 100
# Step 9791 Loss 0.07350299 Correct 98 out of 100
# Step 9792 Loss 0.039453287 Correct 98 out of 100
# Step 9793 Loss 0.04350085 Correct 99 out of 100
# Step 9794 Loss 0.010534668 Correct 100 out of 100
# Step 9795 Loss 0.03511126 Correct 98 out of 100
# Step 9796 Loss 0.11021553 Correct 98 out of 100
# Step 9797 Loss 0.030262373 Correct 99 out of 100
# Step 9798 Loss 0.05970321 Correct 97 out of 100
# Step 9799 Loss 0.017821932 Correct 99 out of 100
# Step 9800 Loss 0.05360637 Correct 99 out of 100
# Step 9801 Loss 0.05704934 Correct 99 out of 100
# Step 9802 Loss 0.030948954 Correct 98 out of 100
# Step 9803 Loss 0.024303084 Correct 99 out of 100
# Step 9804 Loss 0.011395868 Correct 100 out of 100
# Step 9805 Loss 0.02586488 Correct 99 out of 100
# Step 9806 Loss 0.05591851 Correct 99 out of 100
# Step 9807 Loss 0.01233517 Correct 100 out of 100
# Step 9808 Loss 0.054516837 Correct 99 out of 100
# Step 9809 Loss 0.013794851 Correct 100 out of 100
# Step 9810 Loss 0.119316444 Correct 99 out of 100
# Step 9811 Loss 0.023505725 Correct 99 out of 100
# Step 9812 Loss 0.02343055 Correct 100 out of 100
# Step 9813 Loss 0.053211194 Correct 98 out of 100
# Step 9814 Loss 0.009808999 Correct 100 out of 100
# Step 9815 Loss 0.055399533 Correct 98 out of 100
# Step 9816 Loss 0.00896104 Correct 100 out of 100
# Step 9817 Loss 0.0471829 Correct 99 out of 100
# Step 9818 Loss 0.107621714 Correct 98 out of 100
# Step 9819 Loss 0.01353701 Correct 100 out of 100
# Step 9820 Loss 0.020973809 Correct 99 out of 100
# Step 9821 Loss 0.023210378 Correct 99 out of 100
# Step 9822 Loss 0.02873337 Correct 99 out of 100
# Step 9823 Loss 0.10501149 Correct 97 out of 100
# Step 9824 Loss 0.043917928 Correct 98 out of 100
# Step 9825 Loss 0.0337142 Correct 99 out of 100
# Step 9826 Loss 0.13409515 Correct 98 out of 100
# Step 9827 Loss 0.008563707 Correct 100 out of 100
# Step 9828 Loss 0.03014915 Correct 99 out of 100
# Step 9829 Loss 0.02456902 Correct 99 out of 100
# Step 9830 Loss 0.038335755 Correct 99 out of 100
# Step 9831 Loss 0.05929153 Correct 97 out of 100
# Step 9832 Loss 0.0330639 Correct 99 out of 100
# Step 9833 Loss 0.09149711 Correct 97 out of 100
# Step 9834 Loss 0.059867345 Correct 98 out of 100
# Step 9835 Loss 0.02041859 Correct 100 out of 100
# Step 9836 Loss 0.049253237 Correct 97 out of 100
# Step 9837 Loss 0.030075235 Correct 98 out of 100
# Step 9838 Loss 0.003260008 Correct 100 out of 100
# Step 9839 Loss 0.040461816 Correct 99 out of 100
# Step 9840 Loss 0.037701786 Correct 98 out of 100
# Step 9841 Loss 0.041704584 Correct 98 out of 100
# Step 9842 Loss 0.0034177594 Correct 100 out of 100
# Step 9843 Loss 0.01857281 Correct 100 out of 100
# Step 9844 Loss 0.020241119 Correct 100 out of 100
# Step 9845 Loss 0.04928836 Correct 98 out of 100
# Step 9846 Loss 0.0989416 Correct 97 out of 100
# Step 9847 Loss 0.03308411 Correct 99 out of 100
# Step 9848 Loss 0.011329992 Correct 100 out of 100
# Step 9849 Loss 0.019016609 Correct 100 out of 100
# Step 9850 Loss 0.0149451075 Correct 100 out of 100
# Step 9851 Loss 0.015226738 Correct 100 out of 100
# Step 9852 Loss 0.021288447 Correct 99 out of 100
# Step 9853 Loss 0.011142334 Correct 100 out of 100
# Step 9854 Loss 0.008302688 Correct 100 out of 100
# Step 9855 Loss 0.008017512 Correct 100 out of 100
# Step 9856 Loss 0.06475101 Correct 99 out of 100
# Step 9857 Loss 0.013375386 Correct 100 out of 100
# Step 9858 Loss 0.050113387 Correct 98 out of 100
# Step 9859 Loss 0.029359946 Correct 99 out of 100
# Step 9860 Loss 0.008647216 Correct 100 out of 100
# Step 9861 Loss 0.041527174 Correct 99 out of 100
# Step 9862 Loss 0.016470362 Correct 99 out of 100
# Step 9863 Loss 0.053767286 Correct 99 out of 100
# Step 9864 Loss 0.08286188 Correct 98 out of 100
# Step 9865 Loss 0.019364886 Correct 99 out of 100
# Step 9866 Loss 0.014949106 Correct 100 out of 100
# Step 9867 Loss 0.037069894 Correct 99 out of 100
# Step 9868 Loss 0.024739694 Correct 99 out of 100
# Step 9869 Loss 0.010315615 Correct 100 out of 100
# Step 9870 Loss 0.0287584 Correct 99 out of 100
# Step 9871 Loss 0.05226697 Correct 98 out of 100
# Step 9872 Loss 0.02653608 Correct 99 out of 100
# Step 9873 Loss 0.025333397 Correct 99 out of 100
# Step 9874 Loss 0.022043893 Correct 99 out of 100
# Step 9875 Loss 0.014845811 Correct 100 out of 100
# Step 9876 Loss 0.08139059 Correct 98 out of 100
# Step 9877 Loss 0.019727902 Correct 100 out of 100
# Step 9878 Loss 0.026204322 Correct 99 out of 100
# Step 9879 Loss 0.054204244 Correct 99 out of 100
# Step 9880 Loss 0.016386863 Correct 99 out of 100
# Step 9881 Loss 0.037234806 Correct 98 out of 100
# Step 9882 Loss 0.041768704 Correct 99 out of 100
# Step 9883 Loss 0.033900537 Correct 99 out of 100
# Step 9884 Loss 0.048087496 Correct 99 out of 100
# Step 9885 Loss 0.016981596 Correct 100 out of 100
# Step 9886 Loss 0.016608471 Correct 100 out of 100
# Step 9887 Loss 0.08587809 Correct 96 out of 100
# Step 9888 Loss 0.027839616 Correct 99 out of 100
# Step 9889 Loss 0.07274377 Correct 97 out of 100
# Step 9890 Loss 0.047076635 Correct 97 out of 100
# Step 9891 Loss 0.008522562 Correct 100 out of 100
# Step 9892 Loss 0.019430362 Correct 100 out of 100
# Step 9893 Loss 0.044453602 Correct 98 out of 100
# Step 9894 Loss 0.014609086 Correct 100 out of 100
# Step 9895 Loss 0.017862497 Correct 100 out of 100
# Step 9896 Loss 0.037641406 Correct 99 out of 100
# Step 9897 Loss 0.017078333 Correct 100 out of 100
# Step 9898 Loss 0.040810056 Correct 99 out of 100
# Step 9899 Loss 0.023628524 Correct 99 out of 100
# Step 9900 Loss 0.05212091 Correct 98 out of 100
# Step 9901 Loss 0.03635242 Correct 99 out of 100
# Step 9902 Loss 0.06652337 Correct 98 out of 100
# Step 9903 Loss 0.08888754 Correct 95 out of 100
# Step 9904 Loss 0.029315138 Correct 98 out of 100
# Step 9905 Loss 0.028651167 Correct 98 out of 100
# Step 9906 Loss 0.04917521 Correct 98 out of 100
# Step 9907 Loss 0.01371576 Correct 100 out of 100
# Step 9908 Loss 0.009073713 Correct 100 out of 100
# Step 9909 Loss 0.04767285 Correct 97 out of 100
# Step 9910 Loss 0.01826863 Correct 100 out of 100
# Step 9911 Loss 0.04826874 Correct 99 out of 100
# Step 9912 Loss 0.025567198 Correct 99 out of 100
# Step 9913 Loss 0.031254366 Correct 98 out of 100
# Step 9914 Loss 0.021624913 Correct 99 out of 100
# Step 9915 Loss 0.020650202 Correct 99 out of 100
# Step 9916 Loss 0.016544497 Correct 100 out of 100
# Step 9917 Loss 0.009694238 Correct 100 out of 100
# Step 9918 Loss 0.0119351875 Correct 100 out of 100
# Step 9919 Loss 0.025951318 Correct 99 out of 100
# Step 9920 Loss 0.022728775 Correct 100 out of 100
# Step 9921 Loss 0.03471331 Correct 99 out of 100
# Step 9922 Loss 0.025703862 Correct 99 out of 100
# Step 9923 Loss 0.018078819 Correct 99 out of 100
# Step 9924 Loss 0.08604621 Correct 98 out of 100
# Step 9925 Loss 0.017564503 Correct 100 out of 100
# Step 9926 Loss 0.046111397 Correct 98 out of 100
# Step 9927 Loss 0.044237275 Correct 98 out of 100
# Step 9928 Loss 0.030794648 Correct 98 out of 100
# Step 9929 Loss 0.02102777 Correct 100 out of 100
# Step 9930 Loss 0.017540695 Correct 99 out of 100
# Step 9931 Loss 0.02534122 Correct 99 out of 100
# Step 9932 Loss 0.02981519 Correct 99 out of 100
# Step 9933 Loss 0.026212616 Correct 99 out of 100
# Step 9934 Loss 0.031765923 Correct 98 out of 100
# Step 9935 Loss 0.020723388 Correct 99 out of 100
# Step 9936 Loss 0.05393462 Correct 97 out of 100
# Step 9937 Loss 0.038625926 Correct 98 out of 100
# Step 9938 Loss 0.010202185 Correct 100 out of 100
# Step 9939 Loss 0.048653506 Correct 99 out of 100
# Step 9940 Loss 0.007825924 Correct 100 out of 100
# Step 9941 Loss 0.013293084 Correct 99 out of 100
# Step 9942 Loss 0.015982753 Correct 99 out of 100
# Step 9943 Loss 0.007236253 Correct 100 out of 100
# Step 9944 Loss 0.021965802 Correct 99 out of 100
# Step 9945 Loss 0.0128287 Correct 100 out of 100
# Step 9946 Loss 0.02658837 Correct 98 out of 100
# Step 9947 Loss 0.01059366 Correct 100 out of 100
# Step 9948 Loss 0.025500888 Correct 99 out of 100
# Step 9949 Loss 0.07463337 Correct 97 out of 100
# Step 9950 Loss 0.031734034 Correct 99 out of 100
# Step 9951 Loss 0.03458209 Correct 98 out of 100
# Step 9952 Loss 0.047411337 Correct 97 out of 100
# Step 9953 Loss 0.03820912 Correct 99 out of 100
# Step 9954 Loss 0.052635036 Correct 99 out of 100
# Step 9955 Loss 0.024979243 Correct 98 out of 100
# Step 9956 Loss 0.03211961 Correct 98 out of 100
# Step 9957 Loss 0.02760143 Correct 99 out of 100
# Step 9958 Loss 0.03375129 Correct 98 out of 100
# Step 9959 Loss 0.08148501 Correct 98 out of 100
# Step 9960 Loss 0.025310438 Correct 99 out of 100
# Step 9961 Loss 0.009798483 Correct 100 out of 100
# Step 9962 Loss 0.03900509 Correct 99 out of 100
# Step 9963 Loss 0.053753033 Correct 98 out of 100
# Step 9964 Loss 0.023818944 Correct 99 out of 100
# Step 9965 Loss 0.042212587 Correct 98 out of 100
# Step 9966 Loss 0.038199726 Correct 99 out of 100
# Step 9967 Loss 0.021855459 Correct 99 out of 100
# Step 9968 Loss 0.018990193 Correct 99 out of 100
# Step 9969 Loss 0.02040143 Correct 100 out of 100
# Step 9970 Loss 0.0643656 Correct 97 out of 100
# Step 9971 Loss 0.06934063 Correct 97 out of 100
# Step 9972 Loss 0.042616148 Correct 97 out of 100
# Step 9973 Loss 0.035918646 Correct 99 out of 100
# Step 9974 Loss 0.11024798 Correct 98 out of 100
# Step 9975 Loss 0.03070041 Correct 98 out of 100
# Step 9976 Loss 0.033331156 Correct 99 out of 100
# Step 9977 Loss 0.07885991 Correct 97 out of 100
# Step 9978 Loss 0.03079071 Correct 98 out of 100
# Step 9979 Loss 0.04797001 Correct 99 out of 100
# Step 9980 Loss 0.020626321 Correct 99 out of 100
# Step 9981 Loss 0.02723299 Correct 99 out of 100
# Step 9982 Loss 0.009420178 Correct 100 out of 100
# Step 9983 Loss 0.03564611 Correct 99 out of 100
# Step 9984 Loss 0.04279293 Correct 98 out of 100
# Step 9985 Loss 0.045295037 Correct 99 out of 100
# Step 9986 Loss 0.08610115 Correct 98 out of 100
# Step 9987 Loss 0.009909184 Correct 100 out of 100
# Step 9988 Loss 0.060660515 Correct 99 out of 100
# Step 9989 Loss 0.047498554 Correct 97 out of 100
# Step 9990 Loss 0.060181264 Correct 99 out of 100
# Step 9991 Loss 0.032773785 Correct 99 out of 100
# Step 9992 Loss 0.07238887 Correct 98 out of 100
# Step 9993 Loss 0.023950635 Correct 99 out of 100
# Step 9994 Loss 0.025301684 Correct 99 out of 100
# Step 9995 Loss 0.041326713 Correct 99 out of 100
# Step 9996 Loss 0.029769914 Correct 99 out of 100
# Step 9997 Loss 0.037513956 Correct 99 out of 100
# Step 9998 Loss 0.016385175 Correct 100 out of 100
# Step 9999 Loss 0.033915542 Correct 99 out of 100
# Loss for 3000 randomly chosen documents is 0.6335191 correct labels is 2556 out of 3000
